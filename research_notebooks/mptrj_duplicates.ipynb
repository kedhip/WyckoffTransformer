# %%
import gzip
import pickle
with gzip.open("cache/matbench_discovery_mp_trj_full_v2/data.pkl.gz", "rb") as f:
    dataset_pd = pickle.load(f)

# %%
from evaluation.novelty import record_to_augmented_fingerprint

# %%
from pandarallel import pandarallel
pandarallel.initialize()
for dataset in dataset_pd.values():
    dataset["fingerprint"] = dataset.parallel_apply(record_to_augmented_fingerprint, axis=1)
# Out:
# INFO: Pandarallel will run on 24 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
import pandas as pd
mptrj = pd.concat((dataset_pd['train'], dataset_pd['val']), axis=0)
wbm = dataset_pd['test']

# %%
mptrj_groups = mptrj.groupby("fingerprint")

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
mptrj_groups.formation_energy_per_atom.std().hist(bins=300, ax=ax)
ax.set_xlim(0, 1)
ax.set_xlabel("Formation energy per atom standard deviation for the same Wyckoff");

# %%
duplicates = mptrj_groups.apply(len)
# Out:
# /tmp/ipykernel_1662927/1782743068.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   duplicates = mptrj_groups.apply(len)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
duplicates.hist(bins=1000, ax=ax)
ax.set_xlim(0, 100);

# %%
wbm_duplicates = wbm.groupby("fingerprint").apply(len)
# Out:
# /tmp/ipykernel_1662927/3018316197.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   wbm_duplicates = wbm.groupby("fingerprint").apply(len)

# %%
fig, ax = plt.subplots()
wbm_duplicates.hist(bins=10, ax=ax);

# %%
fig, ax = plt.subplots()
wbm.groupby("fingerprint").formation_energy_per_atom.std().hist(bins=5000, ax=ax)
ax.set_xlim(0, 0.02);

# %%
len(wbm.groupby("fingerprint"))
# Out:
# 230636

# %%
len(wbm)
# Out:
# 256963

# %%
filtered_mptrj = mptrj.loc[mptrj.groupby("fingerprint").formation_energy_per_atom.idxmin()]

# %%
len(filtered_mptrj), len(mptrj), len(filtered_mptrj) / len(mptrj)
# Out:
# (152714, 1580395, 0.09663027281154395)

# %%
filtered_mptrj.fingerprint.iloc[0]
# Out:
# (1,
#  frozenset({frozenset({((Element Na, '1', 0), 8),
#                        ((Element Li, '1', 0), 8),
#                        ((Element V, '1', 0), 12),
#                        ((Element P, '1', 0), 8),
#                        ((Element O, '1', 0), 24)})}))

# %%
mptrj.fingerprint.iloc[7]
# Out:
# (6,
#  frozenset({frozenset({((Element Fe, 'm', 0), 6),
#                        ((Element Fe, 'm', 1), 6),
#                        ((Element O, 'm', 0), 6),
#                        ((Element O, 'm', 1), 6),
#                        ((Element F, 'm', 0), 6),
#                        ((Element F, 'm', 1), 6)})}))
