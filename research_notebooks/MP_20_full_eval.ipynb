# %%
import pandas as pd
from evaluation.generated_dataset import GeneratedDataset, load_all_from_config
from evaluation.novelty import NoveltyFilter, filter_by_unique_structure
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from evaluation.generated_dataset import GeneratedDataset, load_all_from_config
#       3 from evaluation.novelty import NoveltyFilter, filter_by_unique_structure
#
# ModuleNotFoundError: No module named 'evaluation'

# %%
all_datasets = load_all_from_config()

# %%
novelty_reference = pd.concat([
    all_datasets[('split', 'train')].data,
    all_datasets[('split', 'val')].data], axis=0, verify_integrity=True)
novelty_reference_set = frozenset(novelty_reference.fingerprint)
novelty_filter = NoveltyFilter(novelty_reference)

# %%
import evaluation.statistical_evaluator
import importlib
importlib.reload(evaluation.statistical_evaluator)
test_unique = filter_by_unique_structure(all_datasets[('split', 'test')].data)
test_novel = novelty_filter.get_novel(test_unique)
test_evaluator = evaluation.statistical_evaluator.StatisticalEvaluator(test_novel)

# %%
from tqdm.notebook import tqdm
sample_size = 992
sample_size_big = 10000
results = pd.DataFrame(index=pd.Index(all_datasets.keys(), tupleize_cols=False),
    columns=["Unique992", f"Unique{sample_size_big}", "Novel WY", "Novel SM",
        "StructVal", "SMACT",
        "& sites EMD", "& sites KS", "& #elements KS", "& #elements EMD",
        "#DoF KS", "#DoF EMD",
        "density EMD", "E EMD",
        "COV-R", "COV-P",
        "& SG chi2", "& elements chi2",
        "S.U.N. 0", "S.U.N. 0.08"])

for transformations, dataset in tqdm(all_datasets.items()):
    if "corrected_chgnet_ehull" in dataset.data.columns:
        has_e_hull = dataset.data.corrected_chgnet_ehull.notnull()
        sample_for_unique = dataset.data.loc[has_e_hull].sample(sample_size)
    else:
        sample_for_unique = dataset.data.sample(sample_size)
    if len(sample_for_unique) < sample_size:
        raise ValueError(f"Dataset {transformations} has less than {sample_size} entries")
    unique_sample = filter_by_unique_structure(sample_for_unique)
    results.loc[[transformations], "Unique992"] = len(unique_sample) / len(sample_for_unique)

    if len(dataset.data) >= sample_size_big:
        big_sample_for_unique = dataset.data.sample(sample_size_big)
        big_unique_sample = filter_by_unique_structure(big_sample_for_unique)
        results.loc[[transformations], f"Unique{sample_size_big}"] = len(big_unique_sample) / len(big_sample_for_unique)
    
    unique = filter_by_unique_structure(dataset.data)
    if len(transformations) != 2 or transformations[1] not in ("train", "val"):
        is_novel = ~unique.fingerprint.isin(novelty_reference_set)
        novel_wy = unique.loc[is_novel]
        results.loc[[transformations], "Novel WY"] = len(novel_wy) / len(unique)
        novel = novelty_filter.get_novel(unique)
        results.loc[[transformations], "Novel SM"] = len(novel) / len(unique)
    else:
        novel = unique

    if "smact_validity" in dataset.data.columns:
        results.loc[[transformations], "StructVal"] = novel.structural_validity.mean()
        results.loc[[transformations], "SMACT"] = novel.smact_validity.mean()
    
    results.loc[[transformations], "& sites EMD"] = test_evaluator.get_num_sites_emd(novel)
    results.loc[[transformations], "& sites KS"] = test_evaluator.get_num_sites_ks(novel).statistic
    results.loc[[transformations], "& #elements KS"] = test_evaluator.get_num_elements_ks(novel).statistic
    results.loc[[transformations], "& #elements EMD"] = test_evaluator.get_num_elements_emd(novel)
    results.loc[[transformations], "#DoF KS"] = test_evaluator.get_dof_ks(novel).statistic
    results.loc[[transformations], "#DoF EMD"] = test_evaluator.get_dof_emd(novel)
    if "structure" in dataset.data.columns:
        results.loc[[transformations], "density EMD"] = test_evaluator.get_density_emd(novel)
        results.loc[[transformations], "E EMD"] = test_evaluator.get_cdvae_e_emd(novel)
        cov_metrics = test_evaluator.get_coverage(novel.cdvae_crystal)    
        results.loc[[transformations], "COV-R"] = cov_metrics["cov_recall"]
        results.loc[[transformations], "COV-P"] = cov_metrics["cov_precision"]

    results.loc[[transformations], "& SG chi2"] = test_evaluator.get_sg_chi2(novel)
    results.loc[[transformations], "& elements chi2"] = test_evaluator.get_elements_chi2(novel)

    if "corrected_chgnet_ehull" in dataset.data.columns:
        total_with_ehull = has_e_hull.sum()
        stable_008 = (novel.corrected_chgnet_ehull < 0.08).sum()
        stable_0 = (novel.corrected_chgnet_ehull <= 0).sum()
        results.loc[[transformations], "S.U.N. 0"] = stable_0 / total_with_ehull
        results.loc[[transformations], "S.U.N. 0.08"] = stable_008 / total_with_ehull
results.to_csv("evaluation_results.csv")
results
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
#                                                  Unique992 Unique10000  \
# (WyckoffTransformer,)                                  1.0      0.9887
# (WyckoffTransformer, CrySPR, CHGNet_fix)               1.0         NaN
# (WyckoffTransformer, CrySPR, CHGNet_free)              1.0         NaN
# (WyckoffTransformer, CrySPR, CHGNet_fix_release)       1.0         NaN
# (WyckoffTransformer, DiffCSP++)                        1.0         NaN
# (WyckoffTransformer, DiffCSP++, CHGNet_fix)            1.0         NaN
# (WyckoffTransformer, DiffCSP++, CHGNet_free)           1.0         NaN
# (CrystalFormer,)                                  0.995968         NaN
# (CrystalFormer, CHGNet_fix_release)               0.995968         NaN
# (DiffCSP,)                                        0.995968      0.9788
# (DiffCSP, CHGNet_fix)                             0.995968         NaN
# (DiffCSP, CHGNet_no_relax)                        0.997984      0.9788
# (DiffCSP++,)                                      0.998992       0.986
# (DiffCSP++, CHGNet_fix_release)                   0.998992         NaN
# (FlowMM,)                                              1.0         NaN
# (FlowMM-relaxed,)                                 0.997984         NaN
# (split, train)                                         1.0      0.9999
# (split, test)                                          1.0         NaN
# (split, test, CHGNet_fix)                              1.0         NaN
# (split, val)                                           1.0         NaN
#
#                                                   Novel WY  Novel SM  \
# (WyckoffTransformer,)                             0.906746  0.906746
# (WyckoffTransformer, CrySPR, CHGNet_fix)             0.894       0.9
# (WyckoffTransformer, CrySPR, CHGNet_free)            0.899     0.902
# (WyckoffTransformer, CrySPR, CHGNet_fix_release)     0.894       0.9
# (WyckoffTransformer, DiffCSP++)                      0.892     0.895
# (WyckoffTransformer, DiffCSP++, CHGNet_fix)          0.892     0.895
# (WyckoffTransformer, DiffCSP++, CHGNet_free)         0.893     0.896
# (CrystalFormer,)                                  0.759799  0.782915
# (CrystalFormer, CHGNet_fix_release)               0.748988  0.769231
# (DiffCSP,)                                        0.905394  0.910094
# (DiffCSP, CHGNet_fix)                             0.896586  0.900602
# (DiffCSP, CHGNet_no_relax)                        0.905394  0.910094
# (DiffCSP++,)                                      0.892596  0.896755
# (DiffCSP++, CHGNet_fix_release)                   0.891892  0.896897
# (FlowMM,)                                          0.93273  0.939367
# (FlowMM-relaxed,)                                 0.887488  0.894396
# (split, train)                                         NaN       NaN
# (split, test)                                      0.97369  0.999558
# (split, test, CHGNet_fix)                            0.977     0.994
# (split, val)                                           NaN       NaN
#
#                                                  StructVal     SMACT  \
# (WyckoffTransformer,)                                  NaN       NaN
# (WyckoffTransformer, CrySPR, CHGNet_fix)          0.996667  0.804444
# (WyckoffTransformer, CrySPR, CHGNet_free)         0.998891  0.804878
# (WyckoffTransformer, CrySPR, CHGNet_fix_release)  0.995556  0.804444
# (WyckoffTransformer, DiffCSP++)                   0.997765  0.803352
# (WyckoffTransformer, DiffCSP++, CHGNet_fix)       0.996648  0.803352
# (WyckoffTransformer, DiffCSP++, CHGNet_free)      0.996652  0.803571
# (CrystalFormer,)                                  0.915276  0.827985
# (CrystalFormer, CHGNet_fix_release)               0.868421  0.823684
# (DiffCSP,)                                             1.0  0.820162
# (DiffCSP, CHGNet_fix)                                  1.0  0.809365
# (DiffCSP, CHGNet_no_relax)                             1.0  0.820162
# (DiffCSP++,)                                      0.999321  0.847207
# (DiffCSP++, CHGNet_fix_release)                        1.0  0.850446
# (FlowMM,)                                         0.966602  0.825412
# (FlowMM-relaxed,)                                      1.0  0.819274
# (split, train)                                         1.0  0.904213
# (split, test)                                          1.0  0.910529
# (split, test, CHGNet_fix)                              1.0  0.899396
# (split, val)                                           1.0  0.905373
#
#                                                  & sites EMD & sites KS  \
# (WyckoffTransformer,)                               0.308085   0.047539
# (WyckoffTransformer, CrySPR, CHGNet_fix)            0.289786   0.049822
# (WyckoffTransformer, CrySPR, CHGNet_free)           3.527339   0.181762
# (WyckoffTransformer, CrySPR, CHGNet_fix_release)    0.728166     0.0576
# (WyckoffTransformer, DiffCSP++)                     0.302982   0.052069
# (WyckoffTransformer, DiffCSP++, CHGNet_fix)         0.276166   0.046483
# (WyckoffTransformer, DiffCSP++, CHGNet_free)        1.100497   0.084207
# (CrystalFormer,)                                    0.538527   0.119484
# (CrystalFormer, CHGNet_fix_release)                 0.490962   0.112552
# (DiffCSP,)                                          4.858541   0.430642
# (DiffCSP, CHGNet_fix)                               4.680893   0.415289
# (DiffCSP, CHGNet_no_relax)                          4.858541   0.430642
# (DiffCSP++,)                                        0.282707   0.044223
# (DiffCSP++, CHGNet_fix_release)                     0.354235   0.059869
# (FlowMM,)                                           5.474531   0.508998
# (FlowMM-relaxed,)                                   5.423009    0.48409
# (split, train)                                       0.06896   0.011754
# (split, test)                                            0.0        0.0
# (split, test, CHGNet_fix)                           0.170712   0.023178
# (split, val)                                        0.052504   0.008141
#
#                                                  & #elements KS  \
# (WyckoffTransformer,)                                  0.051512
# (WyckoffTransformer, CrySPR, CHGNet_fix)               0.054736
# (WyckoffTransformer, CrySPR, CHGNet_free)              0.054159
# (WyckoffTransformer, CrySPR, CHGNet_fix_release)       0.054736
# (WyckoffTransformer, DiffCSP++)                        0.055071
# (WyckoffTransformer, DiffCSP++, CHGNet_fix)            0.055071
# (WyckoffTransformer, DiffCSP++, CHGNet_free)            0.05478
# (CrystalFormer,)                                       0.113093
# (CrystalFormer, CHGNet_fix_release)                    0.111841
# (DiffCSP,)                                             0.183151
# (DiffCSP, CHGNet_fix)                                  0.163743
# (DiffCSP, CHGNet_no_relax)                             0.183151
# (DiffCSP++,)                                           0.185032
# (DiffCSP++, CHGNet_fix_release)                        0.202102
# (FlowMM,)                                              0.074226
# (FlowMM-relaxed,)                                      0.071219
# (split, train)                                          0.00577
# (split, test)                                               0.0
# (split, test, CHGNet_fix)                              0.009972
# (split, val)                                           0.007426
#
#                                                  & #elements EMD   #DoF KS  \
# (WyckoffTransformer,)                                   0.082897   0.06078
# (WyckoffTransformer, CrySPR, CHGNet_fix)                 0.09607  0.047661
# (WyckoffTransformer, CrySPR, CHGNet_free)               0.094715  0.260991
# (WyckoffTransformer, CrySPR, CHGNet_fix_release)         0.09607  0.066549
# (WyckoffTransformer, DiffCSP++)                         0.098926  0.052602
# (WyckoffTransformer, DiffCSP++, CHGNet_fix)             0.098926  0.040311
# (WyckoffTransformer, DiffCSP++, CHGNet_free)            0.098798  0.096921
# (CrystalFormer,)                                        0.211421  0.107023
# (CrystalFormer, CHGNet_fix_release)                     0.201472  0.093277
# (DiffCSP,)                                              0.333874  0.392276
# (DiffCSP, CHGNet_fix)                                   0.293636  0.406591
# (DiffCSP, CHGNet_no_relax)                              0.333874  0.392276
# (DiffCSP++,)                                            0.454557  0.053566
# (DiffCSP++, CHGNet_fix_release)                         0.503632  0.072264
# (FlowMM,)                                               0.128604  0.493736
# (FlowMM-relaxed,)                                       0.130643  0.492564
# (split, train)                                          0.011017  0.014449
# (split, test)                                                0.0       0.0
# (split, test, CHGNet_fix)                               0.014134  0.021466
# (split, val)                                            0.012809  0.009057
#
#                                                    #DoF EMD density EMD  \
# (WyckoffTransformer,)                               0.87334         NaN
# (WyckoffTransformer, CrySPR, CHGNet_fix)           0.771315    0.740661
# (WyckoffTransformer, CrySPR, CHGNet_free)         13.542323    0.741352
# (WyckoffTransformer, CrySPR, CHGNet_fix_release)   2.372089    0.744049
# (WyckoffTransformer, DiffCSP++)                    0.891831    0.654749
# (WyckoffTransformer, DiffCSP++, CHGNet_fix)        0.743227    0.672095
# (WyckoffTransformer, DiffCSP++, CHGNet_free)       3.970189    0.686427
# (CrystalFormer,)                                   1.530515    0.435835
# (CrystalFormer, CHGNet_fix_release)                1.356467    0.641448
# (DiffCSP,)                                        15.002943    0.644331
# (DiffCSP, CHGNet_fix)                              15.75411    0.822378
# (DiffCSP, CHGNet_no_relax)                        15.002943    0.644331
# (DiffCSP++,)                                       0.806255    0.178746
# (DiffCSP++, CHGNet_fix_release)                     1.04385    0.147837
# (FlowMM,)                                         18.205769    0.212267
# (FlowMM-relaxed,)                                 18.993034    0.489733
# (split, train)                                     0.197462    0.049378
# (split, test)                                           0.0         0.0
# (split, test, CHGNet_fix)                          0.538472    0.080452
# (split, val)                                       0.102557    0.037124
#
#                                                      E EMD     COV-R  \
# (WyckoffTransformer,)                                  NaN       NaN
# (WyckoffTransformer, CrySPR, CHGNet_fix)          0.054106  0.986667
# (WyckoffTransformer, CrySPR, CHGNet_free)         0.049437  0.990022
# (WyckoffTransformer, CrySPR, CHGNet_fix_release)  0.053159  0.986667
# (WyckoffTransformer, DiffCSP++)                   0.056445  0.992179
# (WyckoffTransformer, DiffCSP++, CHGNet_fix)       0.050328  0.992179
# (WyckoffTransformer, DiffCSP++, CHGNet_free)      0.048668  0.992188
# (CrystalFormer,)                                  0.210034  0.994865
# (CrystalFormer, CHGNet_fix_release)               0.099555  0.998684
# (DiffCSP,)                                        0.071421  0.997194
# (DiffCSP, CHGNet_fix)                             0.052409  0.995541
# (DiffCSP, CHGNet_no_relax)                        0.071421  0.997194
# (DiffCSP++,)                                      0.074176  0.995476
# (DiffCSP++, CHGNet_fix_release)                   0.036122  0.993304
# (FlowMM,)                                         0.046205  0.996896
# (FlowMM-relaxed,)                                 0.035512   0.99669
# (split, train)                                    0.015128  0.997641
# (split, test)                                          0.0       1.0
# (split, test, CHGNet_fix)                         0.039176       1.0
# (split, val)                                      0.016321   0.99801
#
#                                                      COV-P  & SG chi2  \
# (WyckoffTransformer,)                                  NaN   0.056931
# (WyckoffTransformer, CrySPR, CHGNet_fix)          0.967374    0.21402
# (WyckoffTransformer, CrySPR, CHGNet_free)         0.963282   2.477927
# (WyckoffTransformer, CrySPR, CHGNet_fix_release)  0.967153    0.22206
# (WyckoffTransformer, DiffCSP++)                   0.964388   0.209501
# (WyckoffTransformer, DiffCSP++, CHGNet_fix)       0.967927   0.211308
# (WyckoffTransformer, DiffCSP++, CHGNet_free)      0.966711   0.334708
# (CrystalFormer,)                                  0.935744   0.301981
# (CrystalFormer, CHGNet_fix_release)               0.951338   0.276231
# (DiffCSP,)                                        0.997125   6.985953
# (DiffCSP, CHGNet_fix)                             0.962066   7.988511
# (DiffCSP, CHGNet_no_relax)                        0.997125   6.985953
# (DiffCSP++,)                                      0.997014   0.069114
# (DiffCSP++, CHGNet_fix_release)                   0.957974    0.25525
# (FlowMM,)                                         0.995023  12.877917
# (FlowMM-relaxed,)                                  0.99635  12.423176
# (split, train)                                    0.999558   0.025811
# (split, test)                                          1.0        0.0
# (split, test, CHGNet_fix)                         0.970582   0.143034
# (split, val)                                       0.99823   0.035257
#
#                                                  & elements chi2  S.U.N. 0  \
# (WyckoffTransformer,)                                   0.013147       NaN
# (WyckoffTransformer, CrySPR, CHGNet_fix)                0.040208  0.129129
# (WyckoffTransformer, CrySPR, CHGNet_free)               0.040299  0.158158
# (WyckoffTransformer, CrySPR, CHGNet_fix_release)        0.039926  0.138138
# (WyckoffTransformer, DiffCSP++)                         0.039057       NaN
# (WyckoffTransformer, DiffCSP++, CHGNet_fix)             0.039057     0.124
# (WyckoffTransformer, DiffCSP++, CHGNet_free)            0.039265     0.127
# (CrystalFormer,)                                        0.091822       NaN
# (CrystalFormer, CHGNet_fix_release)                     0.089177  0.198589
# (DiffCSP,)                                              0.070619       NaN
# (DiffCSP, CHGNet_fix)                                   0.099216     0.178
# (DiffCSP, CHGNet_no_relax)                              0.070619     0.106
# (DiffCSP++,)                                             0.03035       NaN
# (DiffCSP++, CHGNet_fix_release)                         0.047999     0.155
# (FlowMM,)                                               0.012056       NaN
# (FlowMM-relaxed,)                                       0.014638       NaN
# (split, train)                                          0.006377       NaN
# (split, test)                                                0.0       NaN
# (split, test, CHGNet_fix)                               0.035228     0.642
# (split, val)                                            0.006944       NaN
#
#                                                  S.U.N. 0.08
# (WyckoffTransformer,)                                    NaN
# (WyckoffTransformer, CrySPR, CHGNet_fix)            0.376376
# (WyckoffTransformer, CrySPR, CHGNet_free)           0.451451
# (WyckoffTransformer, CrySPR, CHGNet_fix_release)    0.392392
# (WyckoffTransformer, DiffCSP++)                          NaN
# (WyckoffTransformer, DiffCSP++, CHGNet_fix)            0.367
# (WyckoffTransformer, DiffCSP++, CHGNet_free)           0.379
# (CrystalFormer,)                                         NaN
# (CrystalFormer, CHGNet_fix_release)                 0.376008
# (DiffCSP,)                                               NaN
# (DiffCSP, CHGNet_fix)                                  0.574
# (DiffCSP, CHGNet_no_relax)                              0.35
# (DiffCSP++,)                                             NaN
# (DiffCSP++, CHGNet_fix_release)                        0.414
# (FlowMM,)                                                NaN
# (FlowMM-relaxed,)                                        NaN
# (split, train)                                           NaN
# (split, test)                                            NaN
# (split, test, CHGNet_fix)                              0.987
# (split, val)                                             NaN

# %%
raw_test_evaluator = evaluation.statistical_evaluator.StatisticalEvaluator(all_datasets[('split', 'test')].data)
cdvae_table = pd.DataFrame(index=pd.Index(all_datasets.keys(), tupleize_cols=False),
    columns=[
        "StructVal", "SMACT",
        "COV-R", "COV-P",
        "density EMD", "E EMD", "#elements EMD"])
sample_size = 992
for transformations, dataset in tqdm(all_datasets.items()):
    if "structure" in dataset.data.columns:
        cdvae_table.loc[[transformations], "SMACT"] = dataset.data.smact_validity.mean()
        cdvae_table.loc[[transformations], "StructVal"] = dataset.data.structural_validity.mean()
        valid = dataset.data[dataset.data.naive_validity]
        cov_metrics = raw_test_evaluator.get_coverage(valid.cdvae_crystal)
        cdvae_table.loc[[transformations], "COV-R"] = cov_metrics["cov_recall"]
        cdvae_table.loc[[transformations], "COV-P"] = cov_metrics["cov_precision"]
        cdvae_table.loc[[transformations], "density EMD"] = raw_test_evaluator.get_density_emd(valid)
        cdvae_table.loc[[transformations], "E EMD"] = raw_test_evaluator.get_cdvae_e_emd(valid)
        cdvae_table.loc[[transformations], "#elements EMD"] = raw_test_evaluator.get_num_elements_emd(valid)
cdvae_table.to_csv("cdvae_metrics_table.csv")
cdvae_table
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
#                                                  StructVal     SMACT  \
# (WyckoffTransformer,)                                  NaN       NaN
# (WyckoffTransformer, CrySPR, CHGNet_fix)             0.997     0.814
# (WyckoffTransformer, CrySPR, CHGNet_free)            0.999     0.814
# (WyckoffTransformer, CrySPR, CHGNet_fix_release)     0.996     0.814
# (WyckoffTransformer, DiffCSP++)                      0.998     0.814
# (WyckoffTransformer, DiffCSP++, CHGNet_fix)          0.997     0.814
# (WyckoffTransformer, DiffCSP++, CHGNet_free)         0.997     0.814
# (CrystalFormer,)                                  0.933934   0.84985
# (CrystalFormer, CHGNet_fix_release)               0.899194   0.84879
# (DiffCSP,)                                             1.0     0.832
# (DiffCSP, CHGNet_fix)                                  1.0     0.825
# (DiffCSP, CHGNet_no_relax)                             1.0     0.832
# (DiffCSP++,)                                        0.9994    0.8513
# (DiffCSP++, CHGNet_fix_release)                        1.0     0.858
# (FlowMM,)                                         0.968694  0.831066
# (FlowMM-relaxed,)                                      1.0  0.828271
# (split, train)                                         1.0  0.904223
# (split, test)                                          1.0  0.910458
# (split, test, CHGNet_fix)                              1.0     0.899
# (split, val)                                           1.0  0.905383
#
#                                                      COV-R     COV-P  \
# (WyckoffTransformer,)                                  NaN       NaN
# (WyckoffTransformer, CrySPR, CHGNet_fix)          0.987685  0.959319
# (WyckoffTransformer, CrySPR, CHGNet_free)          0.99016  0.954897
# (WyckoffTransformer, CrySPR, CHGNet_fix_release)   0.98767   0.95943
# (WyckoffTransformer, DiffCSP++)                   0.995074  0.958103
# (WyckoffTransformer, DiffCSP++, CHGNet_fix)       0.992602  0.958545
# (WyckoffTransformer, DiffCSP++, CHGNet_free)      0.992602  0.956113
# (CrystalFormer,)                                  0.996226  0.945611
# (CrystalFormer, CHGNet_fix_release)                 0.9987  0.954455
# (DiffCSP,)                                        0.998197  0.995136
# (DiffCSP, CHGNet_fix)                             0.996364  0.951802
# (DiffCSP, CHGNet_no_relax)                        0.998197  0.995136
# (DiffCSP++,)                                      0.996709  0.995357
# (DiffCSP++, CHGNet_fix_release)                   0.994172  0.954787
# (FlowMM,)                                         0.997261   0.99392
# (FlowMM-relaxed,)                                 0.997119  0.995578
# (split, train)                                    0.997962  0.999226
# (split, test)                                          1.0  0.999005
# (split, test, CHGNet_fix)                              1.0  0.963962
# (split, val)                                      0.998169  0.997457
#
#                                                  density EMD     E EMD  \
# (WyckoffTransformer,)                                    NaN       NaN
# (WyckoffTransformer, CrySPR, CHGNet_fix)            0.392825  0.078476
# (WyckoffTransformer, CrySPR, CHGNet_free)           0.404807  0.064897
# (WyckoffTransformer, CrySPR, CHGNet_fix_release)    0.387186  0.077984
# (WyckoffTransformer, DiffCSP++)                     0.361735   0.08327
# (WyckoffTransformer, DiffCSP++, CHGNet_fix)         0.327697  0.070343
# (WyckoffTransformer, DiffCSP++, CHGNet_free)         0.33662  0.067816
# (CrystalFormer,)                                    0.193111  0.208384
# (CrystalFormer, CHGNet_fix_release)                 0.185524  0.138571
# (DiffCSP,)                                          0.350799  0.094984
# (DiffCSP, CHGNet_fix)                               0.456087  0.075059
# (DiffCSP, CHGNet_no_relax)                          0.350799  0.094984
# (DiffCSP++,)                                         0.31489  0.069434
# (DiffCSP++, CHGNet_fix_release)                     0.134793  0.035711
# (FlowMM,)                                           0.115293  0.073114
# (FlowMM-relaxed,)                                   0.174168  0.045511
# (split, train)                                       0.08535  0.050269
# (split, test)                                       0.033294  0.034156
# (split, test, CHGNet_fix)                           0.099259   0.04673
# (split, val)                                        0.050448  0.029344
#
#                                                  #elements EMD
# (WyckoffTransformer,)                                      NaN
# (WyckoffTransformer, CrySPR, CHGNet_fix)              0.080551
# (WyckoffTransformer, CrySPR, CHGNet_free)             0.079908
# (WyckoffTransformer, CrySPR, CHGNet_fix_release)      0.081197
# (WyckoffTransformer, DiffCSP++)                       0.078874
# (WyckoffTransformer, DiffCSP++, CHGNet_fix)           0.077776
# (WyckoffTransformer, DiffCSP++, CHGNet_free)          0.077776
# (CrystalFormer,)                                      0.128222
# (CrystalFormer, CHGNet_fix_release)                   0.118921
# (DiffCSP,)                                            0.346595
# (DiffCSP, CHGNet_fix)                                 0.320568
# (DiffCSP, CHGNet_no_relax)                            0.346595
# (DiffCSP++,)                                          0.398878
# (DiffCSP++, CHGNet_fix_release)                        0.45273
# (FlowMM,)                                             0.094281
# (FlowMM-relaxed,)                                     0.092688
# (split, train)                                        0.022898
# (split, test)                                         0.019557
# (split, test, CHGNet_fix)                             0.035021
# (split, val)                                           0.01839
