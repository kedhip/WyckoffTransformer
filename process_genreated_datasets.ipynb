# %%
from evaluation.generated_dataset import GeneratedDataset, StructureStorage, WyckoffStorage
mp_20_test = GeneratedDataset()
mp_20_test.load_structures("cdvae/data/mp_20/test.csv", storage_type=StructureStorage.CDVAE_csv_cif)
mp_20_test.load_wyckoffs("cache/mp_20/data.pkl.gz", storage_type=WyckoffStorage.WTCache, cache_key="test")
# Out:
# Suppressed CIF rounding warnings.
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/core/periodic_table.py:289: UserWarning: No Pauling electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/core/periodic_table.py:289: UserWarning: No Pauling electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(

# %%
mp_20_test.convert_wyckoffs_to_pyxtal()

# %%
mp_20_test.compute_cdvae_crystals(n_jobs=20)
# Out:
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/analysis/local_env.py:4158: UserWarning: No oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   warnings.warn(
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/analysis/local_env.py:3951: UserWarning: CrystalNN: cannot locate an appropriate radius, covalent or atomic radii will be used, this can lead to non-optimal results.
#   warnings.warn(
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/analysis/local_env.py:4158: UserWarning: No oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   warnings.warn(
# ...

# %%
diffcsppp_chg_relaxed = GeneratedDataset()
diffcsppp_chg_relaxed.load_structures("generated/DiffCSP++_mp20_two_step_symmetry", storage_type=StructureStorage.Raymond)
diffcsppp_chg_relaxed.compute_wyckoffs(n_jobs=20)
diffcsppp_chg_relaxed.convert_wyckoffs_to_pyxtal()
diffcsppp_chg_relaxed.compute_cdvae_crystals(n_jobs=20)
# Out:
# Suppressed CIF rounding warnings.
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/analysis/local_env.py:4158: UserWarning: No oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   warnings.warn(
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/analysis/local_env.py:4158: UserWarning: No oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   warnings.warn(
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/analysis/local_env.py:3951: UserWarning: CrystalNN: cannot locate an appropriate radius, covalent or atomic radii will be used, this can lead to non-optimal results.
#   warnings.warn(
# ...

# %%
mp_20_val = GeneratedDataset()
mp_20_val.load_structures("cdvae/data/mp_20/val.csv", storage_type=StructureStorage.CDVAE_csv_cif)
mp_20_val.load_wyckoffs("cache/mp_20/data.pkl.gz", storage_type=WyckoffStorage.WTCache, cache_key="val")
#mp_20_val.convert_wyckoffs_to_pyxtal()
mp_20_val.compute_cdvae_crystals(n_jobs=20)
# Out:
# Suppressed CIF rounding warnings.
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/core/periodic_table.py:289: UserWarning: No Pauling electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
#   warnings.warn(
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/analysis/local_env.py:4158: UserWarning: No oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   warnings.warn(
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/analysis/local_env.py:4158: UserWarning: No oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   warnings.warn(
# ...

# %%
import pickle
import gzip
from pathlib import Path
diffcspp_path = Path("cache", "mp_20", "analysis_datasets", "DiffCSP++", "CHGNet_fix_release.pkl.gz")
diffcspp_path.parent.mkdir(parents=True, exist_ok=True)
with gzip.open(diffcspp_path, "wb") as f:
    pickle.dump(diffcsppp_chg_relaxed, f)

mp_20_test_path = Path("cache", "mp_20", "analysis_datasets", "mp_20", "test.pkl.gz")
mp_20_test_path.parent.mkdir(parents=True, exist_ok=True)
with gzip.open(mp_20_test_path, "wb") as f:
    pickle.dump(mp_20_test, f)

mp_20_val_path = Path("cache", "mp_20", "analysis_datasets", "mp_20", "val.pkl.gz")
mp_20_val_path.parent.mkdir(parents=True, exist_ok=True)
with gzip.open(mp_20_val_path, "wb") as f:
    pickle.dump(mp_20_val, f)

# %%
diffcsp = GeneratedDataset()
diffcsp.load_structures("generated/DiffCSP_mp_20.pt", StructureStorage.DiffCSP_pt)

# %%
#diffcsp.compute_wyckoffs(n_jobs=20)
#diffcsp.convert_wyckoffs_to_pyxtal()
diffcsp.compute_cdvae_crystals(n_jobs=20)
diffcsp_path = Path("cache", "mp_20", "analysis_datasets", "DiffCSP.pkl.gz")
diffcsp_path.parent.mkdir(parents=True, exist_ok=True)
with gzip.open(diffcsp_path, "wb") as f:
    pickle.dump(diffcsp, f)
# Out:
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/analysis/local_env.py:4158: UserWarning: No oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   warnings.warn(
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/analysis/local_env.py:3951: UserWarning: CrystalNN: cannot locate an appropriate radius, covalent or atomic radii will be used, this can lead to non-optimal results.
#   warnings.warn(
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/analysis/local_env.py:4158: UserWarning: No oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   warnings.warn(
# ...

# %%
crystalformer_raw = GeneratedDataset()
crystalformer_raw.load_structures("generated/CrystalFormer_mp_20.csv.gz", StructureStorage.CrystalFormer)
#crystalformer_raw.compute_wyckoffs(n_jobs=20)
#crystalformer_raw.convert_wyckoffs_to_pyxtal()
crystalformer_raw.compute_cdvae_crystals(n_jobs=20)
crystalformer_path = Path("cache", "mp_20", "analysis_datasets", "CrystalFormer.pkl.gz")
crystalformer_path.parent.mkdir(parents=True, exist_ok=True)
with gzip.open(crystalformer_path, "wb") as f:
    pickle.dump(crystalformer_raw, f)
# Out:
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/analysis/local_env.py:4158: UserWarning: No oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   warnings.warn(
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/analysis/local_env.py:3951: UserWarning: CrystalNN: cannot locate an appropriate radius, covalent or atomic radii will be used, this can lead to non-optimal results.
#   warnings.warn(
# /home/kna/.cache/pypoetry/virtualenvs/wyckofftransformer-FeCwefly-py3.10/lib/python3.10/site-packages/pymatgen/analysis/local_env.py:4158: UserWarning: No oxidation states specified on sites! For better results, set the site oxidation states in the structure.
#   warnings.warn(
# ...

# %%
crystlaformer_chgnet = GeneratedDataset()
